# %%
import pandas as pd
pd.set_option('display.max_rows', 5)
reviews = pd.read_csv("./winemag-data-130k-v2.csv", index_col=0)

# %% [markdown]
# # Renaming

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.rename(index={0:'first'})
# Out:
#          country                                        description  \
# first      Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# first                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
# Both the row index and the column index can have their own name attribute. 
# The complimentary rename_axis() method may be used to change these names
reviews.rename_axis("whole wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields        country                                        description  \
# whole wines
# 0               Italy  Aromas include tropical fruit, broom, brimston...
# 1            Portugal  This is ripe and fruity, a wine that is smooth...
# ...               ...                                                ...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
# fields                         designation  points  price           province  \
# whole wines
# 0                             Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                 Avidagos      87   15.0              Douro
# ...                                    ...     ...    ...                ...
# 129969                                 NaN      90   32.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# ...

# %% [markdown]
# # Combining
# concat(), join(), and merge()

# %%
videos1 = pd.read_csv("./videos1.csv")
videos2 = pd.read_csv("./videos2.csv")

# %%
pd.concat([videos1, videos2])
# Out:
#        video_id trending_date            title   channel_title  category_id  \
# 0   xK3nR7P4UiM    2021-01-01  Midnight Garden     Luna Dreams           10
# 1   yH8mB5Kj2Nw    2021-01-01    Mountain Echo  Forest Spirits           10
# ..          ...           ...              ...             ...          ...
# 18  hT_nvWreIhg    2021-01-05   Counting Stars     OneRepublic           10
# 19  60ItHLz5WEA    2021-01-05            Faded     Alan Walker           10
#
#             publish_time                      tags     views   likes  dislikes
# 0   2020-03-15T18:22:31Z  music,ambient,electronic    234567   15678       876
# 1   2019-08-22T12:15:44Z       music,folk,acoustic    456789   23456      1234
# ..                   ...                       ...       ...     ...       ...
# 18  2013-05-31T11:00:00Z            music,pop,rock  98765432  987654      9876
# 19  2015-12-03T22:00:00Z      music,edm,electronic  87654321  876543      8765
#
# [30 rows x 10 columns]

# %%
pd.concat([reviews, videos2]) # diff schemas
# Out:
#      country                                        description   designation  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1   Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# ..       ...                                                ...           ...
# 18       NaN                                                NaN           NaN
# 19       NaN                                                NaN           NaN
#
#     points  price           province region_1 region_2    taster_name  \
# 0     87.0    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1     87.0   15.0              Douro      NaN      NaN     Roger Voss
# ..     ...    ...                ...      ...      ...            ...
# 18     NaN    NaN                NaN      NaN      NaN            NaN
# 19     NaN    NaN                NaN      NaN      NaN            NaN
#
# ...

# %% [markdown]
# join() lets you combine different DataFrame objects which have an index in common

# %%
left = videos1.set_index(['title', 'trending_date'])
right = videos2.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                               video_id_CAN channel_title_CAN  category_id_CAN  \
# title           trending_date
# Midnight Garden 2021-01-01     xK3nR7P4UiM       Luna Dreams               10
# Mountain Echo   2021-01-01     yH8mB5Kj2Nw    Forest Spirits               10
# ...                                    ...               ...              ...
# Solar Winds     2021-01-03     sX9yN4pR7Jw      Space Dreams               10
# Arctic Light    2021-01-04     tY2zP5mS8Kx    Northern Tales               10
#
#                                    publish_time_CAN  \
# title           trending_date
# Midnight Garden 2021-01-01     2020-03-15T18:22:31Z
# Mountain Echo   2021-01-01     2019-08-22T12:15:44Z
# ...                                             ...
# Solar Winds     2021-01-03     2020-08-14T11:27:33Z
# Arctic Light    2021-01-04     2019-06-30T19:48:26Z
#
#                                                 tags_CAN  views_CAN  \
# title           trending_date
# ...

# %% [markdown]
# ---
